# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiAf02/Cholera-Data/blob/main/Cholera_Extension_V19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
from ipywidgets import interact
import scipy.stats as stats
import pandas as pd
import pymc as pm
import seaborn as sns
# from scipy.interpolate import CubicSpline
from scipy.interpolate import splrep, BSpline, CubicSpline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path_to_data = 'https://raw.githubusercontent.com/AndreiAf02/Cholera-Data/main/'
data_all = pd.read_csv(path_to_data + "Chol_Africa_Cumul.csv", sep=",", header=0)
data_all
# Out:
#           Date  Day  Burundi  Comoros  Ethiopia   Kenya   Malawi  Mozambique  \
# 0   2023-01-06    1     12.0      NaN       NaN   347.0   3055.0         NaN
# 1   2023-01-13    8     63.0      NaN       NaN     NaN   7131.0      1014.0
# 2   2023-01-21   16    114.0      NaN       NaN   980.0  12046.0      1776.0
# 3   2023-01-27   22      NaN      NaN       NaN  1336.0  15746.0      2256.0
# 4   2023-02-03   29      NaN      NaN       NaN  1541.0  20172.0      2602.0
# ..         ...  ...      ...      ...       ...     ...      ...         ...
# 61  2024-04-14  465   1317.0    787.0   34662.0     NaN  42594.0     43803.0
# 62  2024-04-20  471   1322.0   1769.0       NaN     NaN  42607.0     44038.0
# 63  2024-04-28  479   1331.0   2498.0   37302.0     NaN  42617.0     44238.0
# 64  2024-05-05  486   1344.0   3864.0   38071.0     NaN  42619.0     44352.0
# 65  2024-05-12  493   1345.0   4976.0   39729.0  8804.0      NaN     44480.0
#
#     Somalia    Sudan   Zambia  Zimbabwe
# ...

# %%
path_to_data = 'https://raw.githubusercontent.com/AndreiAf02/Cholera-Data/main/'
data_Z = pd.read_csv(path_to_data + "Zimb_Updated.csv", sep=",", header=0)
data_Z
# Out:
#           Date  Day  Burundi  Comoros  Ethiopia   Kenya   Malawi  Mozambique  \
# 0   2023-01-06    1     12.0      NaN       NaN   347.0   3055.0         NaN
# 1   2023-01-13    8     63.0      NaN       NaN     NaN   7131.0      1014.0
# 2   2023-01-21   16    114.0      NaN       NaN   980.0  12046.0      1776.0
# 3   2023-01-27   22      NaN      NaN       NaN  1336.0  15746.0      2256.0
# 4   2023-02-03   29      NaN      NaN       NaN  1541.0  20172.0      2602.0
# ..         ...  ...      ...      ...       ...     ...      ...         ...
# 61  2024-04-14  465   1317.0    787.0   34662.0     NaN  42594.0     43803.0
# 62  2024-04-20  471   1322.0   1769.0       NaN     NaN  42607.0     44038.0
# 63  2024-04-28  479   1331.0   2498.0   37302.0     NaN  42617.0     44238.0
# 64  2024-05-05  486   1344.0   3864.0   38071.0     NaN  42619.0     44352.0
# 65  2024-05-12  493   1345.0   4976.0   39729.0  8804.0      NaN     44480.0
#
#     Somalia    Sudan   Zambia  Zimbabwe
# ...

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Burundi'], 'r.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Burundi')
# Out:
# Text(0.5, 1.0, 'Burundi')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Comoros'], 'g.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Comoros')
# Out:
# Text(0.5, 1.0, 'Comoros')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Ethiopia'], 'b.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Ethiopia')
# Out:
# Text(0.5, 1.0, 'Ethiopia')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Kenya'], 'c.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Kenya')
# Out:
# Text(0.5, 1.0, 'Kenya')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Malawi'], 'm.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Malawi')
# Out:
# Text(0.5, 1.0, 'Malawi')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Mozambique'], 'y.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Mozambique')
# Out:
# Text(0.5, 1.0, 'Mozambique')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Somalia'], 'k.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Somalia')
# Out:
# Text(0.5, 1.0, 'Somalia')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Sudan'], 'r.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Sudan')
# Out:
# Text(0.5, 1.0, 'Sudan')

# %%
figure(1, [6, 4])
plot(data_all['Day'], data_all['Zambia'], 'b.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Zambia')
# Out:
# Text(0.5, 1.0, 'Zambia')

# %%
figure(1, [6, 4])
plot(data_Z['Day'], data_Z['Zimbabwe'], 'r.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Zimbabwe')
# Out:
# Text(0.5, 1.0, 'Zimbabwe')

# %% [markdown]
# ##Haiti:

# %%
data_all_haiti= pd.read_csv(path_to_data + "Cholera_Haiti.csv", sep=",", header=0)
data_all_haiti['PNAS']=data_all_haiti['PNAS']*1000

data_all_haiti
# Out:
#      Date     PNAS  PAHO
# 0       1  12000.0     1
# 1       2   7800.0     3
# 2       3  15600.0     4
# 3       4  15050.0    13
# 4       5  15300.0    35
# ..    ...      ...   ...
# 128   129      NaN   130
# 129   130      NaN   142
# 130   131      NaN   156
# 131   132      NaN   165
# 132   133      NaN   159
#
# [133 rows x 3 columns]

# %%
data_all_haiti['PNAS 2']=np.cumsum(data_all_haiti['PNAS'])

data_all_haiti['PAHO 2']=np.cumsum(data_all_haiti['PAHO'])

data_all_haiti

# np.cumsum(data_all_haiti['PNAS 2'])

# for i in range(1,len(data_all_haiti)):
#   data_all_haiti['PNAS 2'][i]=data_all_haiti['PNAS 2'][i-1]+data_all_haiti['PNAS'][i]
# Out:
#      Date     PNAS  PAHO   PNAS 2  PAHO 2
# 0       1  12000.0     1  12000.0       1
# 1       2   7800.0     3  19800.0       4
# 2       3  15600.0     4  35400.0       8
# 3       4  15050.0    13  50450.0      21
# 4       5  15300.0    35  65750.0      56
# ..    ...      ...   ...      ...     ...
# 128   129      NaN   130      NaN   31112
# 129   130      NaN   142      NaN   31254
# 130   131      NaN   156      NaN   31410
# 131   132      NaN   165      NaN   31575
# 132   133      NaN   159      NaN   31734
#
# [133 rows x 5 columns]

# %%
data_haiti_1 = data_all_haiti.drop(columns=['PAHO', 'PAHO 2'])
data_haiti_1 = data_haiti_1[data_haiti_1['PNAS 2'].notnull()]
# data_haiti_1



data_haiti_2 = data_all_haiti.drop(columns=['PNAS', 'PNAS 2', 'PAHO'])

for i in range(len(data_haiti_2)):
  if data_haiti_2['Date'][i] % 7 ==0:
    data_haiti_2['Date'][i] = data_haiti_2['Date'][i]/7
    data_haiti_2['PAHO 2'][i] = data_haiti_2['PAHO 2'][i]
  else:
    data_haiti_2['Date'][i] = None
    data_haiti_2['PAHO 2'][i] = None

data_haiti_2 = data_haiti_2[data_haiti_2['PAHO 2'].notnull()]
data_haiti_2.reset_index(drop=True, inplace=True)
print(data_haiti_2)
# Out:
#     Date   PAHO 2
# 0    1.0    158.0
# 1    2.0   1247.0
# 2    3.0   2424.0
# 3    4.0   4130.0
# 4    5.0   6741.0
# 5    6.0   9494.0
# 6    7.0  12142.0
# 7    8.0  14685.0
# 8    9.0  17142.0
# 9   10.0  19229.0
# 10  11.0  20649.0
# 11  12.0  22020.0
# 12  13.0  23367.0
# 13  14.0  24876.0
# 14  15.0  26524.0
# 15  16.0  28199.0
# 16  17.0  29484.0
# 17  18.0  30719.0
# 18  19.0  31734.0
# <ipython-input-16-963afd60998e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_haiti_2['PAHO 2'][i] = None

# %%
figure(1, [6, 4])
plot(data_haiti_1['Date'], data_haiti_1['PNAS 2'], 'm.')
xlabel('Week', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Haiti (PNAS)')
# Out:
# Text(0.5, 1.0, 'Haiti (PNAS)')

# %%
figure(1, [6, 4])
plot(data_haiti_2['Date'], data_haiti_2['PAHO 2'], 'g.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases', fontsize=12);
title('Haiti (PAHO)')
# Out:
# Text(0.5, 1.0, 'Haiti (PAHO)')

# %% [markdown]
# ## New Model:

# %%
Population_1 = 3500000

data_haiti_3 = pd.DataFrame()
data_haiti_3['Date'] = data_haiti_1['Date']
data_haiti_3['PNAS'] = data_haiti_1['PNAS 2']/Population_1

print(data_haiti_3)

figure(1, [6, 4])
plot(data_haiti_3['Date'], data_haiti_3['PNAS'], 'm.')
xlabel('Week', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Haiti (PNAS)')
# Out:
#     Date      PNAS
# 0      1  0.003429
# 1      2  0.005657
# 2      3  0.010114
# 3      4  0.014414
# 4      5  0.018786
# 5      6  0.023000
# 6      7  0.027429
# 7      8  0.033200
# 8      9  0.038771
# 9     10  0.045657
# 10    11  0.049257
# 11    12  0.052114
# 12    13  0.056114
# 13    14  0.058543
# 14    15  0.061629
# 15    16  0.063063
# 16    17  0.065920
# 17    18  0.068091
# 18    19  0.069506
# 19    20  0.070791
# 20    21  0.072263
# 21    22  0.073606
# 22    23  0.074806
# 23    24  0.077149
# 24    25  0.078234
# 25    26  0.079177
# 26    27  0.080120
# Text(0.5, 1.0, 'Haiti (PNAS)')

# %%
Population_2 = 400000

data_haiti_4 = pd.DataFrame()
data_haiti_4['Date'] = data_haiti_2['Date']
data_haiti_4['PAHO'] = data_haiti_2['PAHO 2']/Population_2

print(data_haiti_4)

figure(1, [6, 4])
plot(data_haiti_4['Date'], data_haiti_4['PAHO'], 'g.')
xlabel('Day', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Haiti (PAHO)')
# Out:
#     Date      PAHO
# 0    1.0  0.000395
# 1    2.0  0.003118
# 2    3.0  0.006060
# 3    4.0  0.010325
# 4    5.0  0.016852
# 5    6.0  0.023735
# 6    7.0  0.030355
# 7    8.0  0.036713
# 8    9.0  0.042855
# 9   10.0  0.048072
# 10  11.0  0.051623
# 11  12.0  0.055050
# 12  13.0  0.058417
# 13  14.0  0.062190
# 14  15.0  0.066310
# 15  16.0  0.070498
# 16  17.0  0.073710
# 17  18.0  0.076798
# 18  19.0  0.079335
# Text(0.5, 1.0, 'Haiti (PAHO)')

# %%
Population_comoros = 60000

data_comoros = data_all[data_all['Comoros'].notnull()]

data_comoros = data_comoros.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Malawi',
                                          'Mozambique', 'Somalia', 'Sudan', 'Zambia', 'Zimbabwe'])

data_comoros['Day_new'] = data_comoros['Day']-data_comoros['Day'].min()+1

data_comoros['Date'] = data_comoros['Day_new']//7+1

data_comoros['Cases (Ratio)'] = data_comoros['Comoros']/Population_comoros

data_comoros = data_comoros.drop(columns=['Day', 'Day_new'])

## Removing first few points:

data_comoros = data_comoros.iloc[4:]

data_comoros['Date']= data_comoros['Date'] - data_comoros['Date'].min() + 1



data_comoros.reset_index(drop=True, inplace=True)

print(data_comoros)

figure(1, [6, 4])
plot(data_comoros['Date'], data_comoros['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Comoros')
# Out:
#    Date  Comoros  Cases (Ratio)
# 0     1    102.0       0.001700
# 1     2    233.0       0.003883
# 2     3    333.0       0.005550
# 3     4    569.0       0.009483
# 4     5    787.0       0.013117
# 5     6   1769.0       0.029483
# 6     7   2498.0       0.041633
# 7     8   3864.0       0.064400
# 8     9   4976.0       0.082933
# Text(0.5, 1.0, 'Comoros')

# %%
Population_kenya = 100000

data_kenya = data_all[data_all['Kenya'].notnull()]

data_kenya = data_kenya.drop(columns=['Burundi', 'Ethiopia', 'Comoros', 'Malawi',
                                          'Mozambique', 'Somalia', 'Sudan', 'Zambia', 'Zimbabwe'])

data_kenya['Day_new'] = data_kenya['Day']-data_kenya['Day'].min()+1

data_kenya['Date'] = data_kenya['Day_new']//7+1

print(data_kenya)


data_kenya['Cases (Ratio)'] = data_kenya['Kenya']/Population_kenya

data_kenya = data_kenya.drop(columns=['Day', 'Day_new'])

data_kenya.reset_index(drop=True, inplace=True)

data_kenya = data_kenya[:-10]

data_kenya.reset_index(drop=True, inplace=True)

# ## Removing first few points:

# data_kenya = data_kenya.iloc[:-13]

# data_kenya['Date']= data_kenya['Date'] - data_kenya['Date'].min() + 1



# data_kenya.reset_index(drop=True, inplace=True)

# print(data_kenya)

figure(1, [6, 4])
plot(data_kenya['Date'], data_kenya['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Kenya')
# Out:
#     Date  Day   Kenya  Day_new
# 0      1    1   347.0        1
# 2      3   16   980.0       16
# 3      4   22  1336.0       22
# 4      5   29  1541.0       29
# 5      6   37  1790.0       37
# 6      7   43  1995.0       43
# 7      8   51  2623.0       51
# 8      9   58  3090.0       58
# 9     10   65  3541.0       65
# 11    12   80  4670.0       80
# 12    13   85  4720.0       85
# 13    14   95  5352.0       95
# 14    16  106  5605.0      106
# 16    18  120  6355.0      120
# 17    19  128  6916.0      128
# 18    20  135  7065.0      135
# 19    21  142  7533.0      142
# 21    23  157  7757.0      157
# 22    24  164  7915.0      164
# 23    27  185  8035.0      185
# 24    28  191  8137.0      191
# 25    29  200  8202.0      200
# 26    30  206  8213.0      206
# 27    31  213  8260.0      213
# 28    32  220  8320.0      220
# 29    33  227  8348.0      227
# 30    34  234  8377.0      234
# 31    35  241  8420.0      241
# 32    36  246  8439.0      246
# ...

# %%
Population_malawi = 450000

data_malawi = data_all[data_all['Malawi'].notnull()]

data_malawi = data_malawi.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Sudan', 'Zambia', 'Zimbabwe'])

data_malawi['Day_new'] = data_malawi['Day']-data_malawi['Day'].min()+1

data_malawi['Date'] = data_malawi['Day_new']//7+1

# print(data_malawi)

data_malawi['Cases (Ratio)'] = data_malawi['Malawi']/Population_malawi

data_malawi = data_malawi.drop(columns=['Day', 'Day_new'])

# ## Removing first few points:

# data_comoros = data_comoros.iloc[4:]

# data_comoros['Date']= data_comoros['Date'] - data_comoros['Date'].min() + 1



data_malawi.reset_index(drop=True, inplace=True)

print(data_malawi)

figure(1, [6, 4])
plot(data_malawi['Date'], data_malawi['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Malawi')
# Out:
#     Date   Malawi  Cases (Ratio)
# 0      1   3055.0       0.006789
# 1      2   7131.0       0.015847
# 2      3  12046.0       0.026769
# 3      4  15746.0       0.034991
# 4      5  20172.0       0.044827
# 5      6  24748.0       0.054996
# 6      7  27850.0       0.061889
# 7      8  31906.0       0.070902
# 8      9  34202.0       0.076004
# 9     10  36081.0       0.080180
# 10    11  37839.0       0.084087
# 11    12  39116.0       0.086924
# 12    13  40120.0       0.089156
# 13    14  40882.0       0.090849
# 14    16  41360.0       0.091911
# 15    17  41650.0       0.092556
# 16    18  41815.0       0.092922
# 17    19  41992.0       0.093316
# 18    20  42085.0       0.093522
# 19    21  42161.0       0.093691
# 20    22  42196.0       0.093769
# 21    23  42197.0       0.093771
# 22    24  42231.0       0.093847
# 23    27  42252.0       0.093893
# 24    28  42262.0       0.093916
# 25    29  42268.0       0.093929
# 26    30  42272.0       0.093938
# ...

# %%
Population_moz = 350000

data_moz = data_all[data_all['Mozambique'].notnull()]

data_moz = data_moz.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Malawi', 'Somalia', 'Sudan', 'Zambia', 'Zimbabwe'])

data_moz['Day_new'] = data_moz['Day']-data_moz['Day'].min()+1

data_moz['Date'] = data_moz['Day_new']//7+1

# print(data_moz)

data_moz['Cases (Ratio)'] = data_moz['Mozambique']/Population_moz

data_moz = data_moz.drop(columns=['Day', 'Day_new'])

## Removing first few points:

data_moz = data_moz.iloc[:25]

data_moz['Date']= data_moz['Date'] - data_moz['Date'].min() + 1



data_moz.reset_index(drop=True, inplace=True)

print(data_moz)

figure(1, [6, 4])
plot(data_moz['Date'], data_moz['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Mozambique')
# Out:
#     Date  Mozambique  Cases (Ratio)
# 0      1      1014.0       0.002897
# 1      2      1776.0       0.005074
# 2      3      2256.0       0.006446
# 3      4      2602.0       0.007434
# 4      5      3938.0       0.011251
# 5      6      4647.0       0.013277
# 6      7      5260.0       0.015029
# 7      8      6690.0       0.019114
# 8      9      7720.0       0.022057
# 9     10      8877.0       0.025363
# 10    11     11923.0       0.034066
# 11    12     19706.0       0.056303
# 12    13     24075.0       0.068786
# 13    15     25638.0       0.073251
# 14    16     27247.0       0.077849
# 15    17     27945.0       0.079843
# 16    18     28647.0       0.081849
# 17    19     28989.0       0.082826
# 18    20     29537.0       0.084391
# 19    21     30007.0       0.085734
# 20    22     30415.0       0.086900
# 21    23     30843.0       0.088123
# 22    26     30953.0       0.088437
# 23    27     31057.0       0.088734
# 24    28     31152.0       0.089006
# ...

# %%
Population_sudan = 120000

data_sudan = data_all[data_all['Sudan'].notnull()]

data_sudan = data_sudan.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Malawi', 'Zambia', 'Zimbabwe'])

data_sudan['Day_new'] = data_sudan['Day']-data_sudan['Day'].min()+1

data_sudan['Date'] = data_sudan['Day_new']//7+1

print(data_sudan)

data_sudan['Cases (Ratio)'] = data_sudan['Sudan']/Population_sudan

data_sudan = data_sudan.drop(columns=['Day', 'Day_new'])

# # ## Removing first few points:

# # data_comoros = data_comoros.iloc[4:]

# # data_comoros['Date']= data_comoros['Date'] - data_comoros['Date'].min() + 1



data_sudan.reset_index(drop=True, inplace=True)

print(data_sudan)

figure(1, [6, 4])
plot(data_sudan['Date'], data_sudan['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Sudan')
# Out:
#     Date  Day    Sudan  Day_new
# 35     1  268    265.0        1
# 38     4  288    520.0       21
# 39     5  296   1320.0       29
# 42     8  317   2228.0       50
# 45    11  338   4881.0       71
# 47    13  353   6642.0       86
# 48    14  360   7970.0       93
# 63    31  479  10295.0      212
#    Date    Sudan  Cases (Ratio)
# 0     1    265.0       0.002208
# 1     4    520.0       0.004333
# 2     5   1320.0       0.011000
# 3     8   2228.0       0.018567
# 4    11   4881.0       0.040675
# 5    13   6642.0       0.055350
# 6    14   7970.0       0.066417
# 7    31  10295.0       0.085792
# Text(0.5, 1.0, 'Sudan')

# %%
Population_zambia = 250000

data_zambia = data_all[data_all['Zambia'].notnull()]

data_zambia = data_zambia.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Malawi', 'Sudan', 'Zimbabwe'])

data_zambia['Day_new'] = data_zambia['Day']-data_zambia['Day'].min()+1

data_zambia['Date'] = data_zambia['Day_new']//7+1

# print(data_zambia)

data_zambia['Cases (Ratio)'] = data_zambia['Zambia']/Population_zambia

data_zambia = data_zambia.drop(columns=['Day', 'Day_new'])

## Removing first few points:

data_zambia = data_zambia.iloc[32:len(data_zambia)-9]

data_zambia['Date']= data_zambia['Date'] - data_zambia['Date'].min() + 1



data_zambia.reset_index(drop=True, inplace=True)

print(data_zambia)

figure(1, [6, 4])
plot(data_zambia['Date'], data_zambia['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Zambia')
# Out:
#     Date   Zambia  Cases (Ratio)
# 0      1   1746.0       0.006984
# 1      2   1940.0       0.007760
# 2      3   2173.0       0.008692
# 3      4   2660.0       0.010640
# 4      5   3298.0       0.013192
# 5      6   3767.0       0.015068
# 6      7   7840.0       0.031360
# 7      8  11886.0       0.047544
# 8      9  14520.0       0.058080
# 9     10  16782.0       0.067128
# 10    11  18547.0       0.074188
# 11    12  19413.0       0.077652
# 12    14  19870.0       0.079480
# Text(0.5, 1.0, 'Zambia')

# %%
Population_zimb = 350000

data_zimb = data_Z[data_Z['Zimbabwe'].notnull()]

data_zimb = data_zimb.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Malawi', 'Sudan', 'Zambia'])

data_zimb['Day_new'] = data_zimb['Day']-data_zimb['Day'].min()+1

data_zimb['Date'] = data_zimb['Day_new']//7+1

# print(data_zimb)

data_zimb['Cases (Ratio)'] = data_zimb['Zimbabwe']/Population_zimb

data_zimb = data_zimb.drop(columns=['Day', 'Day_new'])

## Removing first few points:

data_zimb = data_zimb.iloc[25:]

data_zimb['Date']= data_zimb['Date'] - data_zimb['Date'].min() + 1



data_zimb.reset_index(drop=True, inplace=True)

print(data_zimb)

figure(1, [6, 4])
plot(data_zimb['Date'], data_zimb['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Zimbabwe')
# Out:
#     Date  Zimbabwe  Cases (Ratio)
# 0      1    3652.0       0.010434
# 1      2    3856.0       0.011017
# 2      3    4199.0       0.011997
# 3      4    4538.0       0.012966
# 4      5    4753.0       0.013580
# 5      6    5125.0       0.014643
# 6      7    5651.0       0.016146
# 7      8    6479.0       0.018511
# 8      9    7028.0       0.020080
# 9     10    7865.0       0.022471
# 10    11    9197.0       0.026277
# 11    12   10127.0       0.028934
# 12    13   11221.0       0.032060
# 13    14   12044.0       0.034411
# 14    15   13199.0       0.037711
# 15    16   14767.0       0.042191
# 16    17   16445.0       0.046986
# 17    18   18465.0       0.052757
# 18    19   19545.0       0.055843
# 19    20   21223.0       0.060637
# 20    21   22276.0       0.063646
# 21    22   23549.0       0.067283
# 22    24   25215.0       0.072043
# 23    26   27109.0       0.077454
# 24    27   28098.0       0.080280
# 25    28   29050.0       0.083000
# ...

# %% [markdown]
# ## Running various fits:

# %%
## Haiti 1 (PNAS)

Date = data_haiti_3['Date']
Outbreak_data = data_haiti_3['PNAS']

Population = Population_1

Life_expect = 62.5

init_vals = np.linspace(0.002, 0.004, 3)
# print(init_vals)

# burnin = 12
# burnin_vals=[11, 12, 13]
burnin_vals = np.linspace(11, 13, 3, dtype=int)

Ndays = len(Outbreak_data)

dt = 1
K=600000
# a=0.34
# lamb = 1.75
# sigma = 0.10

a_vals=np.linspace(0.28, 0.32, 5) #[0.30, 0.31, 0.32]
lamb_vals = np.linspace(1.45, 1.65, 5)  #[1.5, 1.55, 1.6, 1.65]
sigma_vals = np.linspace(0.08, 0.12, 5)  #[0.08, 0.10, 0.12]
ratio_vals = np.linspace(16, 24, 5)
# mu = 1/(Life_expect*365)
mu = 1/(Life_expect*52.1)
c=10000/K
r=0.070
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate


# p_A_vals = [0.9, 0.95, 1., 1.05]     ## Asymptomatic recovery
p_A = 1.
p_I = 1.
# p_I_vals = [0.98, 1., 1.02, 1.04]     ## Symptomatic recovery

q_I = 9     ## Fecal contamination from symptomatic
# q_A = 0.45       ## Fecal contamination from asymptomatic


print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('burnin_vals=', burnin_vals)
print('init_vals=', init_vals)
print('ratio_vals=', ratio_vals)
print('----------------------')

SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
burnin_val = pd.DataFrame(columns = ['burnin'])
init_val = pd.DataFrame(columns = ['init'])
ratio_val = pd.DataFrame(columns = ['ratio'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
        for init in init_vals:
          for ratio in ratio_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I, 'burnin=', burnin)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)]=burnin
            init_val.loc[len(init_val)]=init
            ratio_val.loc[len(ratio_val)]=ratio

            I_t = range(Ndays+burnin)
            I_t
            S = np.zeros(Ndays+burnin+1)
            I = np.zeros(Ndays+burnin+1)
            A = np.zeros(Ndays+burnin+1)
            B = np.zeros(Ndays+burnin+1)
            alph=np.zeros(Ndays+burnin+1)
            q_A = q_I/ratio


            # I[0] = 0.003
            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=12000/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in I_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(Ndays+burnin)
            CaseDF = np.zeros(Ndays+burnin)

            for i in I_t:
              # print(i)
              if i in range(burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]


            Sum=0

            for n in I_t:
              for j in I_t:
                  #print("Cases=", Cases[j])
                  #print("j=", j)
                  if n in range(burnin):
                    diff = 0
                  else:
                    if n+1 == DateDF[j]:
                        # print('n+1=', n+1)
                        # print('I=', np.sum(I[:n+1]), 'Case=', CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1])))
                        diff=(np.sum(I[:n+1])-(CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1]))))**2
                    else:
                        diff=0
                  Sum=Sum+diff
                  #print("diff=", diff)

            # print("SumSquares=", Sum)

            SumSq.loc[len(SumSq)] = Sum

            # ParamFits=ParamFits._append(Sum)


            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)


            # plt.figure()
            # plt.plot(DataFrame['Date'], DataFrame['Model']*Population, 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # plt.ylabel('Cumulative Cases')
            # plt.xlabel('Week')
            # plt.title('Haiti (PNAS)')
            # plt.legend()
            # plt.show()

ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']
ParamFit['init'] = init_val['init']
ParamFit['ratio'] = ratio_val['ratio']

# print(ParamFit)


BestFit = pd.DataFrame()
BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

print(BestFit)

# print(ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()])
# Out:
# a_vals= [0.28 0.29 0.3  0.31 0.32]
# lamb_vals= [1.45 1.5  1.55 1.6  1.65]
# sigma_vals= [0.08 0.09 0.1  0.11 0.12]
# mu_vals= 0.0003071017274472169
# p_A_vals= 1.0
# p_I_vals= 1.0
# burnin_vals= [11 12 13]
# init_vals= [0.002 0.003 0.004]
# ratio_vals= [16. 18. 20. 22. 24.]
# ----------------------
#          SumSq    a  Lambda  Sigma        Mu  p_A  p_I  burnin   init  ratio
# 3026  0.000032  0.3     1.6    0.1  0.000307  1.0  1.0      11  0.004   18.0

# %%
## Haiti 1 (PNAS)

Date = data_haiti_3['Date']
Outbreak_data = data_haiti_3['PNAS']
Population = Population_1

burnin = 12

init = BestFit['init']

Ndays = len(Outbreak_data)

dt = 1
K=600000

a = BestFit['a']
lamb = BestFit['Lambda']
sigma = BestFit['Sigma']
burnin= int(BestFit['burnin'])

# mu = BestFit['Mu']

c=10000/K
r=0.070
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate


p_A = BestFit['p_A']     ## Asymptomatic recovery
p_I = BestFit['p_I']     ## Symptomatic recovery
# q_A = 0.45       ## Fecal contamination from asymptomatic
q_I = 9     ## Fecal contamination from symptomatic
q_A = q_I/BestFit['ratio']


I_t = range(Ndays+burnin)
I_t
S = np.zeros(Ndays+burnin+1)
I = np.zeros(Ndays+burnin+1)
A = np.zeros(Ndays+burnin+1)
B = np.zeros(Ndays+burnin+1)
alph=np.zeros(Ndays+burnin+1)


# I[0] = 0.003
I[0] = init
A[0] = I[0]/sigma * (1-sigma)
S[0] = 1-I[0]-A[0]
B[0]=12000/K
alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


for n in I_t:
    alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
    S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
    B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
    I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
    A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


DateDF = np.zeros(Ndays+burnin)
CaseDF = np.zeros(Ndays+burnin)

for i in I_t:
  # print(i)
  if i in range(burnin):
    # print(i+1)
    DateDF[i] = i+1
    CaseDF[i] = None
  else:
    DateDF[i] = Date[i-burnin]+burnin
    CaseDF[i] = Outbreak_data[i-burnin]

# print('DateDF=', len(DateDF))
# print('CaseDF=', len(CaseDF))
# print('I_t=', I_t)

Sum=0

for n in I_t:
  for j in I_t:
      #print("Cases=", Cases[j])
      #print("j=", j)
      if n in range(burnin):
        diff = 0
      else:
        if n+1 == DateDF[j]:
            # print('n+1=', n+1)
            # print('I=', np.sum(I[:n+1]), 'Case=', CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1])))
            diff=(np.sum(I[:n+1])-(CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1]))))**2
        else:
            diff=0
      Sum=Sum+diff
      #print("diff=", diff)

print("SumSquares=", Sum)


DataFrame = pd.DataFrame()
DataFrame['Date'] = DateDF-1
# print(DataFrame['Date'])
# Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max()))  # len(DataFrame['Date']))
# print(Date_smooth)

# DataFrame['Cases'] = Outbreak_data + I[burnin-1]
DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
# DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
DataFrame['Total'] = pd.DataFrame(data=np.cumsum(I+A))

# print(DataFrame['Model'].tail(1)*Population)
Model_cum_Haiti1 = DataFrame['Model'].tail(1)*Population
Total_cum_Haiti1 = DataFrame['Total'].tail(1)*Population

Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max())+1)  # len(DataFrame['Date']))
# print(Date_smooth)

tck = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*50000)

# spline1 = splrep(DataFrame['Date'], DataFrame['Model']*Population, s=0)
# CS1 = CubicSpline(DataFrame['Date'], DataFrame['Model']*Population)
# tck = splrep(DataFrame['Date'], DataFrame['Model']*Population, s=len(DataFrame['Date'])*50000)

# Model_smooth  = CubicSpline(DataFrame['Date']*Population, DataFrame['Model'])

# print(DataFrame)

# print('Difference = ', Outbreak_data[0] - np.sum(I[0:burnin-1]))


figure(1, [6, 4]) #, dpi=600)
# plt.plot(np.cumsum(I), 'r-', label='Model Fit')
# plt.plot(DataFrame['Date'], DataFrame['Model']*Population, 'r-', label='Model Fit')
# plt.plot(Date_smooth[5:]-5, CS1(Date_smooth)[5:], 'r-', label='Model Fit')
# plt.plot(Date_smooth[5:]-5, BSpline(*tck)(Date_smooth)[5:], 'r-', label='Model Fit')
# plt.plot(DataFrame['Date']-5, DataFrame['Cases']*Population, 'b.', label='Cases')
plt.plot(Date_smooth, BSpline(*tck)(Date_smooth), 'r-', label='Model Fit')
plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
# plt.plot(S, 'b-', label='Susceptible')
plt.ylabel('Cumulative Cases')
plt.xlabel('Week')
plt.title('Haiti 2010-2011')
plt.legend()
# Out:
# <ipython-input-37-64b82a725c42>:19: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   burnin= int(BestFit['burnin'])
# <ipython-input-37-64b82a725c42>:49: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   I[0] = init
# <ipython-input-37-64b82a725c42>:50: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   A[0] = I[0]/sigma * (1-sigma)
# <ipython-input-37-64b82a725c42>:53: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)
# ...

# %%
print('Cumulative Reported (Haiti 1):', Model_cum_Haiti1)
print('Cumulative Total (Haiti 1):', Total_cum_Haiti1)
# Out:
# Cumulative Reported (Haiti 1): 37    337509.21594
# Name: Model, dtype: float64
# Cumulative Total (Haiti 1): 37    3.375092e+06
# Name: Total, dtype: float64

# %% [markdown]
# ## Haiti (PAHO):

# %%
## Haiti 2 (PAHO)

Date = data_haiti_4['Date']
Outbreak_data = data_haiti_4['PAHO']

Population = Population_2

Life_expect = 62.5

# burnin = 13
burnin_vals = np.linspace(12, 15, 4, dtype=int)
# burnin_vals=[12, 13, 14]
print(burnin_vals)

init_vals = np.linspace(0.001, 0.004, 4)

Ndays = len(Outbreak_data)

dt = 1
K=600000
a_vals = np.linspace(0.45, 0.5, 5) # [0.485, 0.49, 0.495, 0.5]
lamb_vals = np.linspace(2.1, 2.5, 9) # [2.15, 2.2, 2.25, 2.3]
sigma_vals = np.linspace(0.08, 0.12, 5)  #[0.10, 0.11, 0.12, 0.13]
ratio_vals = np.linspace(12, 20, 5)
# ratio_vals = [16]
# mu = 1/(Life_expect*365)
mu = 1/(Life_expect*52.1)
c=10000/K
r=0.070
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate

p_A = 1. # np.linspace(2., 2.3, 7) #[2., 2.1, 2.2]     ## Asymptomatic recovery
p_I = 1.
# p_I_vals = [0.95, 1.0, 1.05, 1.1]     ## Symptomatic recovery
# q_A = 0.45       ## Fecal contamination from asymptomatic
q_I = 7.2    ## Fecal contamination from symptomatic


print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('init_vals=', init_vals)
print('ratio_vals=', ratio_vals)
print('----------------------')


SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
burnin_val = pd.DataFrame(columns = ['burnin'])
init_val = pd.DataFrame(columns = ['init'])
ratio_val = pd.DataFrame(columns = ['ratio'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
        for init in init_vals:
          for ratio in ratio_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)]=burnin
            init_val.loc[len(init_val)]=init
            ratio_val.loc[len(ratio_val)]=ratio

            I_t = range(Ndays+burnin)
            I_t
            S = np.zeros(Ndays+burnin+1)
            I = np.zeros(Ndays+burnin+1)
            A = np.zeros(Ndays+burnin+1)
            B = np.zeros(Ndays+burnin+1)
            alph=np.zeros(Ndays+burnin+1)
            q_A = q_I/ratio


            # I[0] = 0.003
            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=12000/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in I_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(Ndays+burnin)
            CaseDF = np.zeros(Ndays+burnin)

            for i in I_t:
              # print(i)
              if i in range(burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]


            Sum=0

            for n in I_t:
              for j in I_t:
                  #print("Cases=", Cases[j])
                  #print("j=", j)
                  if n in range(burnin):
                    diff = 0
                  else:
                    if n+1 == DateDF[j]:
                        # print('n+1=', n+1)
                        # print('I=', np.sum(I[:n+1]), 'Case=', CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1])))
                        diff=(np.sum(I[:n+1])-(CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1]))))**2
                    else:
                        diff=0
                  Sum=Sum+diff
                  #print("diff=", diff)

            # print("SumSquares=", Sum)

            SumSq.loc[len(SumSq)] = Sum

            # ParamFits=ParamFits._append(Sum)


            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)


            # plt.figure()
            # plt.plot(DataFrame['Date'], DataFrame['Model']*Population, 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # plt.ylabel('Cumulative Cases')
            # plt.xlabel('Week')
            # plt.title('Haiti (PNAS)')
            # plt.legend()
            # plt.show()

ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']
ParamFit['init'] = init_val['init']
ParamFit['ratio'] = ratio_val['ratio']

# print(ParamFit)


BestFit = pd.DataFrame()
BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

print(BestFit)

# print(ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()])
# Out:
# [12 13 14 15]
# a_vals= [0.45   0.4625 0.475  0.4875 0.5   ]
# lamb_vals= [2.1  2.15 2.2  2.25 2.3  2.35 2.4  2.45 2.5 ]
# sigma_vals= [0.08 0.09 0.1  0.11 0.12]
# mu_vals= 0.0003071017274472169
# p_A_vals= 1.0
# p_I_vals= 1.0
# init_vals= [0.001 0.002 0.003 0.004]
# ratio_vals= [12. 14. 16. 18. 20.]
# ----------------------
#          SumSq       a  Lambda  Sigma        Mu  p_A  p_I  burnin   init  \
# 5488  0.000047  0.4625     2.3   0.11  0.000307  1.0  1.0      14  0.002
#
#       ratio
# 5488   18.0

# %%
a_vals = BestFit['a']
lamb_vals = BestFit['Lambda']
sigma_vals = BestFit['Sigma']
burnin_vals = BestFit['burnin']
init = BestFit['init']
q_A = q_I/BestFit['ratio']

SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
burnin_val = pd.DataFrame(columns = ['burnin'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)]=burnin

            I_t = range(Ndays+burnin)
            I_t
            S = np.zeros(Ndays+burnin+1)
            I = np.zeros(Ndays+burnin+1)
            A = np.zeros(Ndays+burnin+1)
            B = np.zeros(Ndays+burnin+1)
            alph=np.zeros(Ndays+burnin+1)


            # I[0] = 0.003
            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=12000/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in I_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(Ndays+burnin)
            CaseDF = np.zeros(Ndays+burnin)

            for i in I_t:
              # print(i)
              if i in range(burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]


            Sum=0

            for n in I_t:
              for j in I_t:
                  #print("Cases=", Cases[j])
                  #print("j=", j)
                  if n in range(burnin):
                    diff = 0
                  else:
                    if n+1 == DateDF[j]:
                        # print('n+1=', n+1)
                        # print('I=', np.sum(I[:n+1]), 'Case=', CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1])))
                        diff=(np.sum(I[:n+1])-(CaseDF[j]- (Outbreak_data[0] - np.sum(I[0:burnin+1]))))**2
                    else:
                        diff=0
                  Sum=Sum+diff
                  #print("diff=", diff)

            # print("SumSquares=", Sum)

            SumSq.loc[len(SumSq)] = Sum

            # ParamFits=ParamFits._append(Sum)


            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF-1
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))

            DataFrame['Total'] = pd.DataFrame(data=np.cumsum(I+A))
            Model_cum_Haiti2 = DataFrame['Model'].tail(1)*Population
            Total_cum_Haiti2 = DataFrame['Total'].tail(1)*Population
            print('Cumulative Reported (Haiti 2):', Model_cum_Haiti2)
            print('Cumulative Total (Haiti 2):', Total_cum_Haiti2)

            Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max())+1)  # len(DataFrame['Date']))
            # print(Date_smooth)

            tck = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*2000)

            # CS1 = CubicSpline(DataFrame['Date'], DataFrame['Model']*Population)
            # tck = splrep(DataFrame['Date'], DataFrame['Model']*Population, s=len(DataFrame['Date'])*2000)


            plt.figure(dpi=600)
            plt.plot(Date_smooth, BSpline(*tck)(Date_smooth), 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Model']*Population, 'g-', label='Model Fit (true)')
            plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            plt.ylabel('Cumulative Cases')
            plt.xlabel('Week')
            plt.title('Haiti 2022-2023')
            plt.legend()
            plt.show()

ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']
ParamFit['ratio'] = ratio_val['ratio']

print(ParamFit)


# BestFit = pd.DataFrame()
# BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

# print(BestFit)
# Out:
# <ipython-input-54-24ee0d30afc6>:41: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   I[0] = init
# <ipython-input-54-24ee0d30afc6>:53: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
# Cumulative Reported (Haiti 2): 32    39784.089185
# Name: Model, dtype: float64
# Cumulative Total (Haiti 2): 32    361673.538044
# Name: Total, dtype: float64
#       SumSq       a  Lambda  Sigma        Mu  p_A  p_I  burnin  ratio
# 0  0.000047  0.4625     2.3   0.11  0.000307  1.0  1.0      14   12.0

# %% [markdown]
# ## Kenya:

# %%
## Kenya

Population = Population_kenya

Country = 'Kenya'
Date = data_kenya['Date']
Outbreak_data = data_kenya['Cases (Ratio)']

Life_expect = 66.8

# burnin = 6
burnin_vals = np.linspace(5, 7, 3, dtype=int)
# burnin_vals=[6]

init_vals = np.linspace(0.001, 0.004, 4)

Ndays = len(Outbreak_data)

dt = 1

K=60000
a_vals = np.linspace(0.4, 0.8, 5) #[0.36, 0.38, 0.40, 0.41]
lamb_vals = np.linspace(1.9, 2.4, 6) #[2., 2.1, 2.2, 2.3]
sigma_vals = np.linspace(0.06, 0.10, 5) #[0.06, 0.08, 0.10]
# mu = 1/(Life_expect*365)
mu = 1/(Life_expect*52.1)


c=1000/K
r=0.070
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate

p_A = 1. #[0.7, 0.8, 0.9, 1.]     ## Asymptomatic recovery
p_I =  0.9  #np.linspace(0.9, 1., 11) #[0.6, 0.7, 0.8]     ## Symptomatic recovery


# q_A = 0.18       ## Fecal contamination from asymptomatic
q_I = 9     ## Fecal contamination from symptomatic
ratio_vals = np.linspace(16, 24, 5)



print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('init_vals=', init_vals)
print('ratio_vals=', ratio_vals)
print('----------------------')


SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
burnin_val = pd.DataFrame(columns = ['burnin'])
init_val = pd.DataFrame(columns = ['init'])
ratio_val = pd.DataFrame(columns = ['ratio'])

for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
        for init in init_vals:
          for ratio in ratio_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)]=burnin
            init_val.loc[len(init_val)]=init
            ratio_val.loc[len(ratio_val)]=ratio


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)
            q_A = q_I/ratio


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=1200/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF-1
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            # figure(1, [6, 4])
            # plt.plot(DataFrame['Model']*Population, 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # plt.ylabel('Cumulative Cases')
            # plt.xlabel('Week')
            # plt.title(Country)
            # plt.legend()



ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']
ParamFit['init'] = init_val['init']
ParamFit['ratio'] = ratio_val['ratio']


BestFit = pd.DataFrame()
BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

print(BestFit)
# Out:
# a_vals= [0.4 0.5 0.6 0.7 0.8]
# lamb_vals= [1.9 2.  2.1 2.2 2.3 2.4]
# sigma_vals= [0.06 0.07 0.08 0.09 0.1 ]
# mu_vals= 0.0002873332030756146
# p_A_vals= 1.0
# p_I_vals= 0.9
# init_vals= [0.001 0.002 0.003 0.004]
# ratio_vals= [16. 18. 20. 22. 24.]
# ----------------------
#          SumSq    a  Lambda  Sigma        Mu  p_A  p_I  burnin   init  ratio
# 3172  0.004885  0.5     2.3   0.08  0.000287  1.0  0.9       7  0.003   20.0

# %%
a_vals = BestFit['a']
lamb_vals = BestFit['Lambda']
sigma_vals = BestFit['Sigma']
# mu = BestFit['Mu']
init = BestFit['init']
q_A = q_I/BestFit['ratio']

# p_A = BestFit['p_A']     ## Asymptomatic recovery
# p_I = BestFit['p_I']
burnin_vals = BestFit['burnin']


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)]=burnin


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=1200/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF-1
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)

            DataFrame['Total'] = pd.DataFrame(data=np.cumsum(I+A))
            Model_cum_Kenya = DataFrame['Model'].tail(1)*Population
            Total_cum_Kenya = DataFrame['Total'].tail(1)*Population
            print('Cumulative Reported (Kenya)):', Model_cum_Kenya)
            print('Cumulative Total (Kenya):', Total_cum_Kenya)

            Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max())+1)  # len(DataFrame['Date']))
            # print(Date_smooth)

            tck = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*20)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            figure(1, [6, 4], dpi=600)
            # plt.plot(DataFrame['Model']*Population, 'g-', label='Model Fit (true)')
            plt.plot(Date_smooth, BSpline(*tck)(Date_smooth), 'r-', label='Model Fit')
            plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            plt.ylabel('Cumulative Cases')
            plt.xlabel('Week')
            plt.title(Country)
            plt.legend()



ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']


# BestFit = pd.DataFrame()
# BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

# print(BestFit)
# Out:
# <ipython-input-45-463c6571090f>:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   I[0] = init
# <ipython-input-45-463c6571090f>:48: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
# Cumulative Reported (Kenya)): 51    8943.783246
# Name: Model, dtype: float64
# Cumulative Total (Kenya): 51    101520.240784
# Name: Total, dtype: float64

# %% [markdown]
# ##Malawi:

# %%
Population_malawi = 450000

data_malawi = data_all[data_all['Malawi'].notnull()]

data_malawi = data_malawi.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Sudan', 'Zambia', 'Zimbabwe'])

data_malawi['Day_new'] = data_malawi['Day']-data_malawi['Day'].min()+1

data_malawi['Date'] = data_malawi['Day_new']//7+1

# print(data_malawi)

data_malawi['Cases (Ratio)'] = data_malawi['Malawi']/Population_malawi

data_malawi = data_malawi.drop(columns=['Day', 'Day_new'])

# ## Removing first few points:

data_malawi = data_malawi.iloc[:23]

data_malawi['Date']= data_malawi['Date'] - data_malawi['Date'].min() + 1



data_malawi.reset_index(drop=True, inplace=True)

print(data_malawi)

figure(1, [6, 4])
plot(data_malawi['Date'], data_malawi['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Malawi')
# Out:
#     Date   Malawi  Cases (Ratio)
# 0      1   3055.0       0.006789
# 1      2   7131.0       0.015847
# 2      3  12046.0       0.026769
# 3      4  15746.0       0.034991
# 4      5  20172.0       0.044827
# 5      6  24748.0       0.054996
# 6      7  27850.0       0.061889
# 7      8  31906.0       0.070902
# 8      9  34202.0       0.076004
# 9     10  36081.0       0.080180
# 10    11  37839.0       0.084087
# 11    12  39116.0       0.086924
# 12    13  40120.0       0.089156
# 13    14  40882.0       0.090849
# 14    16  41360.0       0.091911
# 15    17  41650.0       0.092556
# 16    18  41815.0       0.092922
# 17    19  41992.0       0.093316
# 18    20  42085.0       0.093522
# 19    21  42161.0       0.093691
# 20    22  42196.0       0.093769
# 21    23  42197.0       0.093771
# 22    24  42231.0       0.093847
# Text(0.5, 1.0, 'Malawi')

# %%
## Malawi

Country = 'Malawi'

Population = Population_malawi

Date = data_malawi['Date']
Outbreak_data = data_malawi['Cases (Ratio)']

Life_expect = 62.5

# burnin = 8
burnin_vals = np.linspace(7, 9, 3, dtype=int)

init_vals = np.linspace(0.005, 0.008, 4)

Ndays = len(Outbreak_data)

dt = 1
K=60000


a_vals = np.linspace(4.5, 5., 5) # [5.1, 5.3, 5.4]
lamb_vals = np.linspace(13, 13.8, 5)
# lamb_vals = np.linspace(5, 10, 11)
sigma_vals = np.linspace(0.07, 0.11, 5) #[0.08, 0.10, 0.12]
# mu = 1/(Life_expect*365)
mu = 1/(Life_expect*52.1)



c=1000/K
r=0.070
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate


p_A = 1. #[1., 1.1, 1.2, 1.3]    ## Asymptomatic recovery
p_I = 0.7   ## Symptomatic Recovery
# p_I_vals = np.linspace(0.65, 1.05, 9)  # [0.74, 0.84, 0.95, 1.]     ## Symptomatic recovery

# p_A_vals = [1.2]    ## Asymptomatic recovery
# p_I_vals = [0.84]     ## Symptomatic recovery

# q_A = 0.18       ## Fecal contamination from asymptomatic
q_I = 7     ## Fecal contamination from symptomatic
ratio_vals = np.linspace(37, 41, 5)


print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('init_vals=', init_vals)
print('ratio_vals=', ratio_vals)
print('----------------------')


SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
burnin_val = pd.DataFrame(columns = ['burnin'])
init_val = pd.DataFrame(columns = ['init'])
ratio_val = pd.DataFrame(columns = ['ratio'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
        for init in init_vals:
          for ratio in ratio_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)] = burnin
            init_val.loc[len(init_val)] = init
            ratio_val.loc[len(ratio_val)] = ratio


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)
            q_A = q_I/ratio


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=1200/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+2]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            # figure(1, [6, 4])
            # plt.plot(DataFrame['Model']*Population, 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # # plt.plot(S, 'b-', label='Susceptible')
            # plt.ylabel('Cumulative Cases')
            # plt.xlabel('Week')
            # plt.title(Country)
            # plt.legend()



ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['burnin'] = burnin_val['burnin']
ParamFit['init'] = init_val['init']
ParamFit['ratio'] = ratio_val['ratio']


BestFit = pd.DataFrame()
BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

print(BestFit)
# Out:
# a_vals= [4.5   4.625 4.75  4.875 5.   ]
# lamb_vals= [13.  13.2 13.4 13.6 13.8]
# sigma_vals= [0.07 0.08 0.09 0.1  0.11]
# mu_vals= 0.0003071017274472169
# p_A_vals= 1.0
# p_I_vals= 0.7
# init_vals= [0.005 0.006 0.007 0.008]
# ratio_vals= [37. 38. 39. 40. 41.]
# ----------------------
#          SumSq      a  Lambda  Sigma        Mu  p_A  p_I  burnin   init  ratio
# 1652  0.000596  4.625    13.0   0.09  0.000307  1.0  0.7       8  0.007   39.0

# %%
a_vals = BestFit['a']
lamb_vals = BestFit['Lambda']
sigma_vals = BestFit['Sigma']
# mu = BestFit['Mu']
q_A = q_I/BestFit['ratio']

init = BestFit['init']

# p_A = BestFit['p_A']     ## Asymptomatic recovery
# p_I = BestFit['p_I']
burnin_vals = BestFit['burnin']

for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for burnin in burnin_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            burnin_val.loc[len(burnin_val)] = burnin


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=1200/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+2]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)

            DataFrame['Total'] = pd.DataFrame(data=np.cumsum(I+A))
            Model_cum_Malawi = DataFrame['Model'].tail(1)*Population
            Total_cum_Malawi = DataFrame['Total'].tail(1)*Population
            print('Cumulative Reported (Malawi):', Model_cum_Malawi)
            print('Cumulative Total (Malawi):', Total_cum_Malawi)

            Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max()))  # len(DataFrame['Date']))
            # print(Date_smooth)

            print('Date_smooth=', len(Date_smooth), "Model=", len(DataFrame['Model']))

            tck = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*17000)
            tck2 = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*2000)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            figure(1, [6, 4]) #, dpi=600)
            # plt.plot(DataFrame['Model']*Population, 'g-', label='Model Fit (true)')
            plt.plot(Date_smooth-1, BSpline(*tck)(Date_smooth), 'r-', label='Model Fit')
            # plt.plot(Date_smooth[:16]-1, BSpline(*tck)(Date_smooth)[:16], 'r-', label='Model Fit')
            # plt.plot(Date_smooth[15:]-1, BSpline(*tck2)(Date_smooth)[15:], 'r-')
            plt.plot(DataFrame['Date'][:-2], DataFrame['Cases'][:-2]*Population, 'b.', label='Cases')
            # plt.plot(S, 'b-', label='Susceptible')
            plt.ylabel('Cumulative Cases')
            plt.xlabel('Week')
            plt.title(Country)
            plt.legend()
# Out:
# <ipython-input-48-1841eca01458>:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   I[0] = init
# <ipython-input-48-1841eca01458>:48: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
# Cumulative Reported (Malawi): 31    58117.538645
# Name: Model, dtype: float64
# Cumulative Total (Malawi): 31    469589.53464
# Name: Total, dtype: float64
# Date_smooth= 32 Model= 32

# %% [markdown]
# ## Zimbabwe:

# %%
Population_zimb = 350000

data_zimb = data_Z[data_Z['Zimbabwe'].notnull()]

data_zimb = data_zimb.drop(columns=['Burundi', 'Ethiopia', 'Kenya', 'Comoros',
                                          'Mozambique', 'Somalia', 'Malawi', 'Sudan', 'Zambia'])

data_zimb['Day_new'] = data_zimb['Day']-data_zimb['Day'].min()+1

data_zimb['Date'] = data_zimb['Day_new']//7+1

# print(data_zimb)

data_zimb['Cases (Ratio)'] = data_zimb['Zimbabwe']/Population_zimb

data_zimb = data_zimb.drop(columns=['Day', 'Day_new'])

## Removing first few points:

data_zimb = data_zimb.iloc[25:]

data_zimb['Date']= data_zimb['Date'] - data_zimb['Date'].min() + 1



data_zimb.reset_index(drop=True, inplace=True)

print(data_zimb)

figure(1, [6, 4])
plot(data_zimb['Date'], data_zimb['Cases (Ratio)'], 'g.')
xlabel('Date', fontsize=12)
ylabel('Cumulative Cases (Ratio)', fontsize=12);
title('Zimbabwe')
# Out:
#     Date  Zimbabwe  Cases (Ratio)
# 0      1    3652.0       0.010434
# 1      2    3856.0       0.011017
# 2      3    4199.0       0.011997
# 3      4    4538.0       0.012966
# 4      5    4753.0       0.013580
# 5      6    5125.0       0.014643
# 6      7    5651.0       0.016146
# 7      8    6479.0       0.018511
# 8      9    7028.0       0.020080
# 9     10    7865.0       0.022471
# 10    11    9197.0       0.026277
# 11    12   10127.0       0.028934
# 12    13   11221.0       0.032060
# 13    14   12044.0       0.034411
# 14    15   13199.0       0.037711
# 15    16   14767.0       0.042191
# 16    17   16445.0       0.046986
# 17    18   18465.0       0.052757
# 18    19   19545.0       0.055843
# 19    20   21223.0       0.060637
# 20    21   22276.0       0.063646
# 21    22   23549.0       0.067283
# 22    24   25215.0       0.072043
# 23    26   27109.0       0.077454
# 24    27   28098.0       0.080280
# 25    28   29050.0       0.083000
# ...

# %%
## Zimbabwe

Country = 'Zimbabwe'

Population = Population_zimb

Date = data_zimb['Date']
Outbreak_data = data_zimb['Cases (Ratio)']  #[:22]

Life_expect = 58.5

burnin = 0

init_vals = np.linspace(0.009, 0.012, 4)

Ndays = len(Outbreak_data)


dt = 1
K=600000
a_vals = np.linspace(0.7, 1.1, 5) #[1.2]
lamb_vals = np.linspace(4, 7, 7) #[6.]
sigma_vals = np.linspace(0.07, 0.11, 5) #[0.10]
# mu = 1/(Life_expect*365)
mu = 1/(Life_expect*52.1)
c=10200/K
r=0.06
c_s = 0.    ## Sanitary Disposal Compliance
c_h = 0.    ## Handwashing compliance
c_f_A = 0.    ## Fecal disposal compliance for asymptomatic
c_f_I = 0.    ## Fecal disposal compliance for symptomatic
nu = 0.      ## Vaccination Rate

p_A = 1.     ## Asymptomatic recovery
p_I = 1.  # np.linspace(0.9, 1., 11) #[0.985]     ## Symptomatic recovery
# q_A = 0.2       ## Fecal contamination from asymptomatic
q_I = 4.5     ## Fecal contamination from symptomatic
ratio_vals = np.linspace(20, 25, 5)


print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('init_vals=', init_vals)
print('ratio_vals=', ratio_vals)
print('----------------------')


SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])
init_val = pd.DataFrame(columns = ['init'])
ratio_val = pd.DataFrame(columns = ['ratio'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
      for init in init_vals:
        for ratio in ratio_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I
            init_val.loc[len(init_val)] = init
            ratio_val.loc[len(ratio_val)] = ratio


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)
            q_A = q_I/ratio


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=17000/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF-1
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            # figure(1, [6, 4])
            # plt.plot(DataFrame['Model']*Population, 'r-', label='Model Fit')
            # plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # plt.plot(DataFrame['Date'][22], DataFrame['Cases'][22]*Population, 'g+', markersize=10)
            # plt.plot(DataFrame['Date'][23], DataFrame['Cases'][23]*Population, 'g+', markersize=10)
            # # plt.plot(25, 25494.0, 'g+', markersize=10)
            # plt.ylabel('Cumulative Cases')
            # plt.xlabel('Week')
            # plt.title(Country)
            # plt.legend()



ParamFit = pd.DataFrame()
ParamFit['SumSq'] = SumSq['SumSquared']
ParamFit['a'] = Aval['a']
ParamFit['Lambda'] = Lambda['Lamda']
ParamFit['Sigma'] = Sigma['Sigma']
ParamFit['Mu'] = Muval['mu']
ParamFit['p_A'] = PA_val['p_A']
ParamFit['p_I'] = PI_val['p_I']
ParamFit['init'] = init_val['init']
ParamFit['ratio'] = ratio_val['ratio']


BestFit = pd.DataFrame()
BestFit = ParamFit.loc[ParamFit['SumSq']==ParamFit['SumSq'].min()]

print(BestFit)
# Out:
# a_vals= [0.7 0.8 0.9 1.  1.1]
# lamb_vals= [4.  4.5 5.  5.5 6.  6.5 7. ]
# sigma_vals= [0.07 0.08 0.09 0.1  0.11]
# mu_vals= 0.00032810013616155654
# p_A_vals= 1.0
# p_I_vals= 1.0
# init_vals= [0.009 0.01  0.011 0.012]
# ratio_vals= [20.   21.25 22.5  23.75 25.  ]
# ----------------------
#       SumSq    a  Lambda  Sigma        Mu  p_A  p_I   init  ratio
# 772  0.0012  0.8     4.0    0.1  0.000328  1.0  1.0  0.011   22.5

# %%
# a_vals = BestFit['a']
# lamb_vals = BestFit['Lambda']
# sigma_vals = BestFit['Sigma']
# p_I = BestFit['p_I']

# a_vals = [1.2]
# lamb_vals = [6.]
# sigma_vals = [0.10]

# p_A = 1.     ## Asymptomatic recovery
# p_I = 1.     ## Symptomatic recovery


a_vals = BestFit['a']
lamb_vals = BestFit['Lambda']
sigma_vals = BestFit['Sigma']
p_I = BestFit['p_I']
init = BestFit['init']
q_A = q_I/BestFit['ratio']

print('a_vals=', a_vals)
print('lamb_vals=', lamb_vals)
print('sigma_vals=', sigma_vals)
print('mu_vals=', mu)
print('p_A_vals=', p_A)
print('p_I_vals=', p_I)
print('----------------------')


SumSq = pd.DataFrame(columns = ['SumSquared'])
Aval = pd.DataFrame(columns = ['a'])
Lambda = pd.DataFrame(columns = ['Lamda'])
Sigma = pd.DataFrame(columns = ['Sigma'])
Muval = pd.DataFrame(columns = ['mu'])
PA_val = pd.DataFrame(columns = ['p_A'])
PI_val = pd.DataFrame(columns = ['p_I'])


for a in a_vals:
  for lamb in lamb_vals:
    for sigma in sigma_vals:
            # print('a=', a, 'lambda=', lamb, 'sigma=', sigma, 'mu=', mu, 'p_A=', p_A, 'p_I=', p_I)
            Aval.loc[len(Aval)] = a
            Lambda.loc[len(Lambda)] = lamb
            Sigma.loc[len(Sigma)] = sigma
            Muval.loc[len(Muval)] = mu
            PA_val.loc[len(PA_val)] = p_A
            PI_val.loc[len(PI_val)] = p_I


            I_t = range(Ndays+burnin)
            MI_t = range(max(Date)+burnin)
            S = np.zeros(max(Date)+burnin+1)
            I = np.zeros(max(Date)+burnin+1)
            A = np.zeros(max(Date)+burnin+1)
            B = np.zeros(max(Date)+burnin+1)
            alph= np.zeros(max(Date)+burnin+1)


            I[0] = init
            A[0] = I[0]/sigma * (1-sigma)
            S[0] = 1-I[0]-A[0]
            B[0]=17000/K
            alph[0]=a*(B[0]-c)/((B[0]-c)+lamb)

            ### Instead of Susceptible = ... 1 - p_S*S[n], we put mu instead of 1 and p_S! The original model is incorrect!


            for n in MI_t:
                alph[n+1]=np.piecewise(B[n], [B[n] < c, B[n] >= c], [0, a*(B[n]-c)/((B[n]-c)+lamb)])
                S[n+1] = S[n]+(-(1-c_s)*(1-c_h)*alph[n]*S[n] + mu - (mu+nu)*S[n])*dt
                B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
                I[n+1] = I[n] + dt*(sigma*(1-c_s)*(1-c_h)*alph[n]*S[n]  - p_I*I[n] - mu*I[n])
                A[n+1] = A[n] + dt*((1-sigma)*(1-c_s)*(1-c_h)*alph[n]*S[n] - p_A*A[n] - mu*A[n])


            DateDF = np.zeros(max(Date) + burnin)
            CaseDF = np.zeros(max(Date) + burnin)

            for i in MI_t:
              # print(i)
              if i in range(burnin) or i in range(Ndays+burnin, max(Date) + burnin):
                # print(i+1)
                DateDF[i] = i+1
                CaseDF[i] = None
              else:
                DateDF[i] = Date[i-burnin]+burnin
                CaseDF[i] = Outbreak_data[i-burnin]
              # else:
              #   DateDF[i] = i+1
              #   CaseDF[i] = None



            DataFrame = pd.DataFrame()
            DataFrame['Date'] = DateDF-1
            # DataFrame['Cases'] = Outbreak_data + I[burnin-1]
            DataFrame['Cases'] = CaseDF - (Outbreak_data[0] - np.sum(I[0:burnin+1]))
            # DataFrame['Model'] = pd.DataFrame(data=I) + Outbreak_data[0]
            DataFrame['Model'] = pd.DataFrame(data=np.cumsum(I))
            # print(DataFrame)

            DataFrame['Total'] = pd.DataFrame(data=np.cumsum(I+A))
            Model_cum_Zimb = DataFrame['Model'].tail(1)*Population
            Total_cum_Zimb = DataFrame['Total'].tail(1)*Population
            print('Cumulative Reported (Zimbabwe):', Model_cum_Zimb)
            print('Cumulative Total (Zimbabwe):', Total_cum_Zimb)

            Date_smooth = np.linspace(DataFrame['Date'].min(), DataFrame['Date'].max(), int(DataFrame['Date'].max())+1)  # len(DataFrame['Date']))
            # print(Date_smooth)

            print('Date_smooth=', len(Date_smooth), "Model=", len(DataFrame['Model']))

            tck = splrep(Date_smooth, DataFrame['Model']*Population, s=len(DataFrame['Date'])*1000)


            Sum=0

            for i in range(len(DataFrame)):
              for n in range(len(DataFrame)-1):
                if (n+1 == DataFrame['Date'][i]):
                  # print('n+1=', n+1, 'Date=', DataFrame['Date'][i], 'Model=', DataFrame['Model'][n+1], 'Cases=', DataFrame['Cases'][i])

                  if np.isnan(DataFrame['Cases'][i]):
                    diff = 0.
                  else:
                     diff = (DataFrame['Model'][n+1] - DataFrame['Cases'][i])**2

                  # print('Difference=', diff)

                Sum=Sum+diff

            SumSq.loc[len(SumSq)] = Sum

            # print(DataFrame[DataFrame[['Cases']].notnull().all(1)])



            figure(1, [6, 4], dpi=600)
            # plt.plot(DataFrame['Model']*Population, 'r-', label='Model Fit')
            plt.plot(Date_smooth, BSpline(*tck)(Date_smooth), 'r-', label='Model Fit')
            plt.plot(DataFrame['Date'], DataFrame['Cases']*Population, 'b.', label='Cases')
            # plt.plot(data_zimb['Date'][22:]-1, data_zimb['Cases (Ratio)'][22:]*Population, 'g+', label='Cases')
            # plt.plot(25, DataFrame['Model'][25]*Population, 'm^')
            # plt.plot(data_zimb['Date'][23]-1, data_zimb['Cases (Ratio)'][23]*Population, 'mx', label='Cases')
            # plt.plot(DataFrame['Date'][22], DataFrame['Cases'][22]*Population, 'g+', markersize=10)
            # plt.plot(DataFrame['Date'][23], DataFrame['Cases'][23]*Population, 'g+', markersize=10)
            # plt.plot(25, 25494.0, 'g+', markersize=10)
            plt.ylabel('Cumulative Cases')
            plt.xlabel('Week')
            plt.title(Country)
            plt.legend()
# Out:
# a_vals= 772    0.8
# Name: a, dtype: float64
# lamb_vals= 772    4.0
# Name: Lambda, dtype: float64
# sigma_vals= 772    0.1
# Name: Sigma, dtype: float64
# mu_vals= 0.00032810013616155654
# p_A_vals= 1.0
# p_I_vals= 772    1.0
# Name: p_I, dtype: float64
# ----------------------
# Cumulative Reported (Zimbabwe): 33    32821.325005
# Name: Model, dtype: float64
# Cumulative Total (Zimbabwe): 33    328213.250048
# Name: Total, dtype: float64
# Date_smooth= 34 Model= 34
# <ipython-input-51-ceaafacd6c9f>:60: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   I[0] = init
# <ipython-input-51-ceaafacd6c9f>:72: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   B[n+1] = B[n]+(r*B[n]*(1-B[n])+(1-c_f_I)*q_I*I[n]+(1-c_f_A)*q_A*A[n])*dt
# ...

# %%
print('Cumulative Reported (Haiti 1):', Model_cum_Haiti1)
print('Cumulative Total (Haiti 1):', Total_cum_Haiti1)
print('------------------------')

print('Cumulative Reported (Haiti 2):', Model_cum_Haiti2)
print('Cumulative Total (Haiti 2):', Total_cum_Haiti2)

print('------------------------')

print('Cumulative Reported (Kenya):', Model_cum_Kenya)
print('Cumulative Total (Kenya):', Total_cum_Kenya)

print('------------------------')

print('Cumulative Reported (Malawi):', Model_cum_Malawi)
print('Cumulative Total (Kenya):', Total_cum_Malawi)

print('------------------------')

print('Cumulative Reported (Zimbabwe):', Model_cum_Zimb)
print('Cumulative Total (Zimbabwe):', Total_cum_Zimb)
# Out:
# Cumulative Reported (Haiti 1): 37    337509.21594
# Name: Model, dtype: float64
# Cumulative Total (Haiti 1): 37    3.375092e+06
# Name: Total, dtype: float64
# ------------------------
# Cumulative Reported (Haiti 2): 32    39784.089185
# Name: Model, dtype: float64
# Cumulative Total (Haiti 2): 32    361673.538044
# Name: Total, dtype: float64
# ------------------------
# Cumulative Reported (Kenya): 51    8943.783246
# Name: Model, dtype: float64
# Cumulative Total (Kenya): 51    101520.240784
# Name: Total, dtype: float64
# ------------------------
# Cumulative Reported (Malawi): 31    58117.538645
# Name: Model, dtype: float64
# Cumulative Total (Kenya): 31    469589.53464
# Name: Total, dtype: float64
# ------------------------
# Cumulative Reported (Zimbabwe): 33    32821.325005
# Name: Model, dtype: float64
# Cumulative Total (Zimbabwe): 33    328213.250048
# Name: Total, dtype: float64

# %%
barWidth = 0.25
# fig = plt.subplots(figsize =(12, 8))

color1 = 'r'
color2 = 'b'

# set height of bar
Model_cum = [float(Model_cum_Haiti1), float(Model_cum_Haiti2), float(Model_cum_Kenya), float(Model_cum_Malawi), float(Model_cum_Zimb)]
Total_cum = [float(Total_cum_Haiti1), float(Total_cum_Haiti2), float(Total_cum_Kenya), float(Total_cum_Malawi), float(Total_cum_Zimb)]

# Set position of bar on X axis
br1 = np.arange(len(Model_cum))
br2 = [x + barWidth for x in br1]

fig, ax = plt.subplots(figsize = (10, 5)) #, dpi=600)
ax2 = ax.twinx()

ax.bar(br1, Model_cum, color ='lightgray', hatch='//', width = barWidth,
        edgecolor =color1, label ='Model')
ax2.bar(br2, Total_cum, color ='lightgray', hatch='\\\\', width = barWidth,
        edgecolor =color2, label ='Total')
ax.set_xlabel('Country', fontsize=15)
plt.xticks([r + barWidth/2 for r in range(len(Model_cum))],
        ['Haiti (2010-2011)', 'Haiti (2022-2023)', 'Kenya', 'Malawi', 'Zimbabwe'])
ax.set_ylabel('Cumulative Reported Cases', color = color1)
ax.tick_params(axis='y', labelcolor=color1)

ax2.set_ylabel('Cumulative Total Cases', color = color2)
ax2.tick_params(axis='y', labelcolor=color2)
ax2.spines['left'].set_color(color1)
ax2.spines['right'].set_color(color2)

# plt.legend()
plt.show()
# Out:
# <ipython-input-81-6ce9d19c35cb>:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   Model_cum = [float(Model_cum_Haiti1), float(Model_cum_Haiti2), float(Model_cum_Kenya), float(Model_cum_Malawi), float(Model_cum_Zimb)]
# <ipython-input-81-6ce9d19c35cb>:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   Total_cum = [float(Total_cum_Haiti1), float(Total_cum_Haiti2), float(Total_cum_Kenya), float(Total_cum_Malawi), float(Total_cum_Zimb)]
